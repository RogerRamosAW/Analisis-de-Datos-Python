# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Estructuras de Datos
#
# ### Series

# %%
obj = pd.Series([1, 2 , 3])
obj
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [1, 2, 3]
# Length: 3, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
obj2 = pd.Series([1, 2 , 3], index=['a', 'f', 'b'])
obj2
# Out:
# a    1
# f    2
# b    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'f', 'b'], dtype='object')

# %%
obj2 = pd.Series([1, 2 , 3], index=['primero', 'segundo', 'tercero'])
obj2
# Out:
# primero    1
# segundo    2
# tercero    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['primero', 'segundo', 'tercero'], dtype='object')

# %%
obj2['segundo']
# Out:
# 2

# %%
obj2['primero'] = 1000
obj2
# Out:
# primero    1000
# segundo       2
# tercero       3
# dtype: int64

# %%
obj2[['primero', 'tercero']]
# Out:
# primero    1000
# tercero       3
# dtype: int64

# %%
obj2[obj2>10]
# Out:
# primero    1000
# dtype: int64

# %%
obj2[obj2<10]
# Out:
# segundo    2
# tercero    3
# dtype: int64

# %%
obj2*10
# Out:
# primero    10000
# segundo       20
# tercero       30
# dtype: int64

# %%
'segundo' in obj2
# Out:
# True

# %%
'quinto' in obj2
# Out:
# False

# %%
data = {'Manzana':5, 'Naranja': 10, 'Mango': 15}
data
# Out:
# {'Manzana': 5, 'Naranja': 10, 'Mango': 15}

# %%
obj3 = pd.Series(data)
obj3
# Out:
# Manzana     5
# Naranja    10
# Mango      15
# dtype: int64

# %%
obj3.to_dict()
# Out:
# {'Manzana': 5, 'Naranja': 10, 'Mango': 15}

# %%
frutas = ['Pera', 'Mango', 'Manzana', 'Naranja']
obj4 = pd.Series(data, index=frutas)
obj4
# Out:
# Pera        NaN
# Mango      15.0
# Manzana     5.0
# Naranja    10.0
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# Pera        True
# Mango      False
# Manzana    False
# Naranja    False
# dtype: bool

# %%
pd.notna(obj4)
# Out:
# Pera       False
# Mango       True
# Manzana     True
# Naranja     True
# dtype: bool

# %%
pd.isna(obj4).sum()
# Out:
# 1

# %%
pd.notna(obj4).sum()
# Out:
# 3

# %% [markdown]
# ### DataFrames

# %%
data = {
    'estados': ['CDMX', 'CDMX', 'CDMX', 'Queretaro', 'Queretaro', 'Queretaro'],
    'agno': [2010, 2015, 2020, 2010, 2015, 2020],
    'pob': [8.8, 8.9, 9.2, 1.8, 2, 2.3]
}
data
# Out:
# {'estados': ['CDMX', 'CDMX', 'CDMX', 'Queretaro', 'Queretaro', 'Queretaro'],
#  'agno': [2010, 2015, 2020, 2010, 2015, 2020],
#  'pob': [8.8, 8.9, 9.2, 1.8, 2, 2.3]}

# %%
frame = pd.DataFrame(data)
frame
# Out:
#      estados  agno  pob
# 0       CDMX  2010  8.8
# 1       CDMX  2015  8.9
# 2       CDMX  2020  9.2
# 3  Queretaro  2010  1.8
# 4  Queretaro  2015  2.0
# 5  Queretaro  2020  2.3

# %%
frame.head(2)
# Out:
#   estados  agno  pob
# 0    CDMX  2010  8.8
# 1    CDMX  2015  8.9

# %%
frame.tail(1)
# Out:
#      estados  agno  pob
# 5  Queretaro  2020  2.3

# %%
pd.DataFrame(data, columns=['agno', 'estados', 'pob'])
# Out:
#    agno    estados  pob
# 0  2010       CDMX  8.8
# 1  2015       CDMX  8.9
# 2  2020       CDMX  9.2
# 3  2010  Queretaro  1.8
# 4  2015  Queretaro  2.0
# 5  2020  Queretaro  2.3

# %%
frame2 = pd.DataFrame(data, columns=['agno', 'estados', 'pob', 'den'])
frame2
# Out:
#    agno    estados  pob  den
# 0  2010       CDMX  8.8  NaN
# 1  2015       CDMX  8.9  NaN
# 2  2020       CDMX  9.2  NaN
# 3  2010  Queretaro  1.8  NaN
# 4  2015  Queretaro  2.0  NaN
# 5  2020  Queretaro  2.3  NaN

# %%
frame2['estados']
# Out:
# 0         CDMX
# 1         CDMX
# 2         CDMX
# 3    Queretaro
# 4    Queretaro
# 5    Queretaro
# Name: estados, dtype: object

# %%
frame2.estados
# Out:
# 0         CDMX
# 1         CDMX
# 2         CDMX
# 3    Queretaro
# 4    Queretaro
# 5    Queretaro
# Name: estados, dtype: object

# %%
frame2[['estados', 'agno']]
# Out:
#      estados  agno
# 0       CDMX  2010
# 1       CDMX  2015
# 2       CDMX  2020
# 3  Queretaro  2010
# 4  Queretaro  2015
# 5  Queretaro  2020

# %%
frame2['den'] = 1000
frame2
# Out:
#    agno    estados  pob   den
# 0  2010       CDMX  8.8  1000
# 1  2015       CDMX  8.9  1000
# 2  2020       CDMX  9.2  1000
# 3  2010  Queretaro  1.8  1000
# 4  2015  Queretaro  2.0  1000
# 5  2020  Queretaro  2.3  1000

# %%
frame2['exceso_pob'] = frame2['pob'] > 8
frame2
# Out:
#    agno    estados  pob   den  exceso_pob
# 0  2010       CDMX  8.8  1000        True
# 1  2015       CDMX  8.9  1000        True
# 2  2020       CDMX  9.2  1000        True
# 3  2010  Queretaro  1.8  1000       False
# 4  2015  Queretaro  2.0  1000       False
# 5  2020  Queretaro  2.3  1000       False

# %%
frame3 = frame2.copy()
frame3
# Out:
#    agno    estados  pob   den  exceso_pob
# 0  2010       CDMX  8.8  1000        True
# 1  2015       CDMX  8.9  1000        True
# 2  2020       CDMX  9.2  1000        True
# 3  2010  Queretaro  1.8  1000       False
# 4  2015  Queretaro  2.0  1000       False
# 5  2020  Queretaro  2.3  1000       False

# %%
frame3 = frame3.drop(index=[1, 4])
frame3
# Out:
#    agno    estados  pob   den  exceso_pob
# 0  2010       CDMX  8.8  1000        True
# 2  2020       CDMX  9.2  1000        True
# 3  2010  Queretaro  1.8  1000       False
# 5  2020  Queretaro  2.3  1000       False

# %%
frame3.drop(columns='den')
# Out:
#    agno    estados  pob  exceso_pob
# 0  2010       CDMX  8.8        True
# 1  2015       CDMX  8.9        True
# 2  2020       CDMX  9.2        True
# 3  2010  Queretaro  1.8       False
# 4  2015  Queretaro  2.0       False
# 5  2020  Queretaro  2.3       False

# %%
frame3
# Out:
#    agno    estados  pob   den  exceso_pob
# 0  2010       CDMX  8.8  1000        True
# 1  2015       CDMX  8.9  1000        True
# 2  2020       CDMX  9.2  1000        True
# 3  2010  Queretaro  1.8  1000       False
# 4  2015  Queretaro  2.0  1000       False
# 5  2020  Queretaro  2.3  1000       False

# %%
frame3[:5]
# Out:
#    agno    estados  pob   den  exceso_pob
# 0  2010       CDMX  8.8  1000        True
# 1  2015       CDMX  8.9  1000        True
# 2  2020       CDMX  9.2  1000        True
# 3  2010  Queretaro  1.8  1000       False
# 4  2015  Queretaro  2.0  1000       False

# %%
frame3[2:]
# Out:
#    agno    estados  pob   den  exceso_pob
# 2  2020       CDMX  9.2  1000        True
# 3  2010  Queretaro  1.8  1000       False
# 4  2015  Queretaro  2.0  1000       False
# 5  2020  Queretaro  2.3  1000       False

# %%
frame3[frame3['pob'] > 8]
# Out:
#    agno estados  pob   den  exceso_pob
# 0  2010    CDMX  8.8  1000        True
# 1  2015    CDMX  8.9  1000        True
# 2  2020    CDMX  9.2  1000        True

# %%
frame3[frame3['pob'] < 8]
# Out:
#    agno    estados  pob   den  exceso_pob
# 3  2010  Queretaro  1.8  1000       False
# 4  2015  Queretaro  2.0  1000       False
# 5  2020  Queretaro  2.3  1000       False

# %%
frame3[frame3['estados'] == 'Queretaro']
# Out:
#    agno    estados  pob   den  exceso_pob
# 3  2010  Queretaro  1.8  1000       False
# 4  2015  Queretaro  2.0  1000       False
# 5  2020  Queretaro  2.3  1000       False

# %%
frame3[frame3['pob'] > 9] = 0
frame3
# Out:
# <ipython-input-85-6e4427cd75e5>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   frame3[frame3['pob'] > 9] = 0
#    agno    estados  pob   den exceso_pob
# 0  2010       CDMX  8.8  1000       True
# 1  2015       CDMX  8.9  1000       True
# 2     0          0  0.0     0          0
# 3  2010  Queretaro  1.8  1000      False
# 4  2015  Queretaro  2.0  1000      False
# 5  2020  Queretaro  2.3  1000      False

# %%
frame3 = frame2.copy()

# %%
indices = ['primero', 'segundo', 'tercero', 'cuarto', 'quinto', 'sexto']
frame3.index = indices
frame3
# Out:
#          agno    estados  pob   den  exceso_pob
# primero  2010       CDMX  8.8  1000        True
# segundo  2015       CDMX  8.9  1000        True
# tercero  2020       CDMX  9.2  1000        True
# cuarto   2010  Queretaro  1.8  1000       False
# quinto   2015  Queretaro  2.0  1000       False
# sexto    2020  Queretaro  2.3  1000       False

# %%
frame2.loc[1]
# Out:
# agno          2015
# estados       CDMX
# pob            8.9
# den           1000
# exceso_pob    True
# Name: 1, dtype: object

# %%
frame3.loc['segundo']
# Out:
# agno          2015
# estados       CDMX
# pob            8.9
# den           1000
# exceso_pob    True
# Name: segundo, dtype: object

# %%
frame3.iloc[1]
# Out:
# agno          2015
# estados       CDMX
# pob            8.9
# den           1000
# exceso_pob    True
# Name: segundo, dtype: object

# %%
frame3.loc[['segundo', 'quinto']]
# Out:
#          agno    estados  pob   den  exceso_pob
# segundo  2015       CDMX  8.9  1000        True
# quinto   2015  Queretaro  2.0  1000       False

# %%
frame3.iloc[[1, 4]]
# Out:
#          agno    estados  pob   den  exceso_pob
# segundo  2015       CDMX  8.9  1000        True
# quinto   2015  Queretaro  2.0  1000       False

# %%
frame3.iloc[[1, 4], [1, 3]]
# Out:
#            estados   den
# segundo       CDMX  1000
# quinto   Queretaro  1000

# %%
frame3.loc[['segundo', 'quinto'], ['estados', 'den']]
# Out:
#            estados   den
# segundo       CDMX  1000
# quinto   Queretaro  1000

# %%
frame3.loc[frame3.pob < 8, ['estados', 'den']]
# Out:
#           estados   den
# cuarto  Queretaro  1000
# quinto  Queretaro  1000
# sexto   Queretaro  1000

# %%
frame3.describe()
# Out:
#               agno       pob     den
# count     6.000000  6.000000     6.0
# mean   2015.000000  5.500000  1000.0
# std       4.472136  3.803157     0.0
# min    2010.000000  1.800000  1000.0
# 25%    2011.250000  2.075000  1000.0
# 50%    2015.000000  5.550000  1000.0
# 75%    2018.750000  8.875000  1000.0
# max    2020.000000  9.200000  1000.0
